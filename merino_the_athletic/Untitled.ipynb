# %%
import json
from groq import Groq
import os

# %%
client =  Groq(api_key = os.environ['GROQ_API_KEY'])

# %%
article = \
"""
What Mikel Merino would bring to Arsenal: Athleticism, defensive duels and back-post runs

The Real Sociedad and Spain midfielder could be heading to Arsenal - this is why they want him and what they would be getting

One of the great things about consuming football in the way that we do — a blur of sights and sounds, colours, movements, structures and names — is that players, for whatever reason, can still catch the eye.

Mikel Merino scored one very obvious goal to draw our attention as his Spain team won the recent European Championship, but there is still something in his aesthetic; the confidence in which he strides from challenge to challenge, chest out and head up, that makes him very easy to like.

Merino, 28, has bossed Real Sociedad’s midfield for years. His affectionate nickname, El Conde (The Count), goes some way to capturing the simple elegance of his game. Rarely flashy, not usually one for long-range screamers or raking switches of play, he goes about his business with minimal fuss, even in one of the most demanding, high-intensity roles in Spanish football.

Already at the heart of one swirling, possession-based system, Merino should have no issues switching to another if the talks to take him to the Emirates Stadium progress. But Arsenal manager Mikel Arteta has seen more than just technical ability in the man he hopes to make his latest left-sided midfield acquisition.

That side of their team has been a slight sticking point in Arsenal’s build-up across the past calendar year, particularly since Granit Xhaka left last July to join Germany’s Bayer Leverkusen.

The original idea of playing Kai Havertz, signed from Chelsea in that same window, as the left-sided No 8 did not quite bring the fluid ball progression that it promised on paper.



Moving Declan Rice, another bought in summer 2023, into that box-to-box role has proven to be an effective solution. But this system places a lot of strain on the three starting midfielders to perform at a consistently high level as the games stack up and the pressure mounts during the run-in.

Merino’s arrival would help to lessen the burden, a dependable figure who has averaged over 40 appearances per season across his six years with Real Sociedad.

He is comfortable playing in that left half-space, where Xhaka used to reside, although he is more of a box-to-box athlete than a tempo-setter from deep.

The heatmap below not only shows the extent of the ground he covers but also his increasing tendency to drop into those holes on the left to receive the ball from his team-mates.

Merino, of course, has previous with the Premier League. He had just turned 21 when he joined Newcastle United from Germany’s Borussia Dortmund in summer 2017, convinced by manager Rafael Benitez to join their post-Premier League promotion project.

“You could see he had class,” Benitez told The Athletic before Euro 2024, when he also revealed Merino had a clause inserted in his contract that would allow him to leave Newcastle if a club from his native Basque region made an offer for him. “He’s good in the air, wins a lot of aerial duels (…), he can control the ball, is capable of playing the final pass, and he gets there at the right time. He just needed a little bit more time.”

Real Sociedad were the Basque side who came calling, just a year later, and Merino’s arrival in San Sebastian — barely 50 miles (83km) from his hometown of Pamplona — would be transformative. Imanol Alguacil, still their manager today, would be appointed five months later, and the young midfielder quickly became a crucial component in a constantly-evolving team.

Merino missed just three games in 2019-20, his first full season under Alguacil, and famously scored the goal that put La Real 4-1 up against Real Madrid at the Bernabeu on their way to ending a three-decade trophy drought by winning the Copa del Rey.

That success was spearheaded by two current Premier League stars; Alexander Isak (now of Newcastle) and, intriguingly, Arsenal’s present captain Martin Odegaard. Alguacil’s side would generally settle into a 4-3-3 shape in possession, with past and future team-mates Odegaard and Merino combining as the two advanced No 8s ahead of Igor Zubeldia, as the passing network below illustrates.

Odegaard, who was on loan from Real Madrid, created nine chances for Merino throughout that season — the third-most prolific partnership in the team — while Merino made 375 passes into the attacking third in La Liga matches, more than any outfield player in the entire division.

In Arsenal’s current system, the two are likely to have the freedom to combine in much the same way. 

Here against Almeria, for example, he first receives an awkward bouncing ball down the left, holding off his marker before laying it back to full-back Javi Galan.
Galan and winger Ander Barrenetxea then look to combine down the flank, but the ball is eventually cleared back into midfield. With Galan and Barrenetxea out of position, Merino is there to step in and win a strong sliding tackle to stop the counter-attack and keep La Real on the front foot.
But Merino is not finished there. As a new move develops down the opposite wing following his intervention, he ghosts towards the penalty area and almost manages to steer the ball home on the slide.
That persistence in the final third was also on show against Real Betis in May, as he charged in to make two tackles on Pablo Fornals, before racing into the box and sliding in what would prove to be his final Real Sociedad goal.

On top of a slick technical game, Merino’s robust defensive contributions make him very attractive to a positional, front-footed team. The only question that remains is his suitability for this Arsenal side, particularly in a role alongside Rice.

If Merino was to take up the left-sided spot, Rice would likely return to the No 6 position. Should this be the case, it remains to be seen whether the England international’s ball progression from that area of the pitch will meet manager Arteta’s high demands. If the Spaniard were to play deeper, maybe even next to Rice in a double pivot, it might necessitate a change of structure, or at least constant communication between the two on when to push forward and when to hold.

But again, if Arsenal are to finally reclaim the Premier League title, more than 20 years on from their previous one, to keep up at the top of the table for an entire season they need to avoid standards dropping at any point.

With the ability to play multiple roles, while adding yet more height, athleticism and box-to-box dominance to the midfield, bringing Merino in, even as a squad player, makes a whole lot of sense.
"""

# %%
def llm(prompt):
    retries = 5
    for i in range(retries):
        try:
            response = client.chat.completions.create(
                model= 'llama-3.1-70b-versatile',
                messages=[{"role": "user", "content": prompt}]
            )
            json_response = response.choices[0].message.content
            return json_response
        except HTTPError as e:
            if e.response.status_code == 429:  # Rate limit error
                retry_after = float(e.response.json()['error']['message'].split('in ')[-1].split('s')[0])
                time.sleep(retry_after)
            else:
                raise
        except Exception as e:
            if i < retries - 1:
                time.sleep(2 ** i)  # Exponential backoff
            else:
                raise

# %%
prompt = """
You are a skilled translator and football expert. 
Translate the provided English article about football into Vietnamese, 
ensuring that all football-related terms are accurately translated and used in the correct context, 
based on the information provided in the technical specifications delimited by triple backticks. 
Please maintain the original article's tone, style, and format. 
The target audience is Vietnamese football fans. 
Provide the translated article in a clear and readable format.

Article: ```{}```
"""
response = llm(prompt.format(article).strip())
print(response)
# Out:
# Bài viết gốc:
#
# Mikel Merino sẽ mang lại điều gì cho Arsenal: Sự thể thao, các cuộc đấu tranh phòng ngự và các đường chạy sau lưng
#
# Tiền vệ của Real Sociedad và Tây Ban Nha có thể sẽ đến với Arsenal - đây là lý do tại sao họ muốn anh ấy và những gì họ sẽ nhận được
#
# Một trong những điều tuyệt vời về việc theo dõi bóng đá theo cách chúng ta làm - một sự kết hợp của hình ảnh, âm thanh, màu sắc, chuyển động, cấu trúc và tên tuổi - là các cầu thủ, vì một lý do nào đó, vẫn có thể thu hút sự chú ý.
#
# Mikel Merino đã ghi một bàn thắng rất rõ ràng để thu hút sự chú ý của chúng ta khi đội tuyển Tây Ban Nha của anh ấy giành chức vô địch giải vô địch châu Âu gần đây, nhưng vẫn còn một điều gì đó trong phong cách của anh ấy; sự tự tin mà anh ấy tiến từ thử thách này sang thử thách khác, ngực phồng và đầu cao, khiến anh ấy rất dễ được yêu thích.
#
# ...
